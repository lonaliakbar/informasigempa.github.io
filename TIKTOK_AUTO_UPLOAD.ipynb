# %% [markdown]
# <a href="https://colab.research.google.com/github/lonaliakbar/informasigempa.github.io/blob/main/TIKTOK_AUTO_UPLOAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Requirement already satisfied: tiktok-uploader in /usr/local/lib/python3.12/dist-packages (1.2.0)
Requirement already satisfied: playwright>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from tiktok-uploader) (1.58.0)
Requirement already satisfied: pydantic>=2.10.6 in /usr/local/lib/python3.12/dist-packages (from tiktok-uploader) (2.12.3)
Requirement already satisfied: pytz>=2025.2 in /usr/local/lib/python3.12/dist-packages (from tiktok-uploader) (2025.2)
Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from tiktok-uploader) (0.10.2)
Requirement already satisfied: pyee<14,>=13 in /usr/local/lib/python3.12/dist-packages (from playwright>=1.58.0->tiktok-uploader) (13.0.1)
Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright>=1.58.0->tiktok-uploader) (3.3.2)
Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->tiktok-uploader) (0.7.0)
Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->tiktok-uploader) (2.41.4)
Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->tiktok-uploader) (4.15.0)
Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.6->tiktok-uploader) (0.4.2)
👇 SILAKAN UPLOAD FILE COOKIES TIKTOK KAMU (NAMA FILE BEBAS) 👇
www.tiktok.com_cookies.txt
www.tiktok.com_cookies.txt(text/plain) - 4828 bytes, last modified: 28/2/2026 - 100% done
[08:23:44] Authenticating browser with cookies
DEBUG:tiktok_uploader:Authenticating browser with cookies
Saving www.tiktok.com_cookies.txt to www.tiktok.com_cookies.txt
✅ File cookies berhasil diterima dan siap digunakan!

--------------------------------------------------

[08:23:44] Mengecek data BMKG terbaru...
⚠️ GEMPA BARU TERDETEKSI: 28 Feb 2026 13:52:07 WIB | Magnitudo 5.6
Mulai proses upload ke TikTok...
❌ Terjadi kesalahan: Invalid path: /content/gempa_terbaru.jpg
Menunggu 5 menit...
# Out:
# ...
# 👇 SILAKAN UPLOAD FILE COOKIES TIKTOK KAMU (NAMA FILE BEBAS) 👇
#      <input type="file" id="files-800d53f8-f007-4eff-891b-15346fb86e24" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-800d53f8-f007-4eff-891b-15346fb86e24">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
